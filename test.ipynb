# %%
import pandas as pd

# %%
df_path = r"C:\Users\nurbe\OneDrive\Desktop\threads_parser\data\english\threads_suicide_en_1762837886.csv"
df = pd.read_csv(df_path)
df.head()
# Out:
#                                                 text  published_on  \
# 0  I’ve carried the thought of ending\nlonger tha...    1762835363
# 1  Everyone should see Nuremberg, if only for the...    1762820282
# 2  Quick stop by Tahquamenom Falls on our way to ...    1762795786
# 3  Nobody glows better than a woman who didn't ge...    1762795446
# 4                          All I want for Christmas…    1762778837
#
#                                 id         code             username  \
# 0  3763258243024807051_67114542802  DQ5x271jeSL  caitlinpwurrell.exe
# 1  3763131732422985429_63472427250  DQ5VF9qEobV            late.july
# 2  3762926248671659308_63073354972  DQ4mXyAEUUs               tjwalz
# 3  3762923399229178449_63371303000  DQ4luUQD4JR         theeashley.b
# 4  3762784067989389821_63390662068  DQ4GCx7AcH9            sads_irl8
#
#    like_count  reply_count  image_count videos  \
# 0           3            0          NaN    NaN
# 1         139            0          NaN    NaN
# ...

# %%
pd.set_option('display.max_colwidth', None)
print(df['text'].head(1))
# Out:
# 0    I’ve carried the thought of ending\nlonger than I’ve carried peace.\nIt lingers in my breathing,\na weight that doesn’t cease.\n\nBut I’ve never used its shadow\nto make another kneel,\nnever played my breaking\nas a weapon they could feel.\n\nWhen I said I wanted silence,\nI meant the noise inside\nnot to guilt, not to haunt,\njust to finally unwind.\n\nSo when they use the word suicide\nas a leash, as a blade, as proof,\nI think of the ones who meant it\nthe ones who told the truth.
# Name: text, dtype: object

# %%
print(df['url'])
# Out:
# 0      https://www.threads.net/@toddsmurray/post/DQ5a...
# 1      https://www.threads.net/@suzielee71/post/DQ3xy...
# 2      https://www.threads.net/@dahyun_dubu7/post/DQ3...
# 3      https://www.threads.net/@james_grissom/post/DQ...
# 4      https://www.threads.net/@babyangel.jpg/post/DO...
#                              ...
# 382    https://www.threads.net/@sidimightbe/post/DQAR...
# 383    https://www.threads.net/@digital_moon_books/po...
# 384    https://www.threads.net/@rubenilagan/post/DP-x...
# 385    https://www.threads.net/@cwinesbitt/post/DP_gG...
# 386    https://www.threads.net/@taylortorrencemusic/p...
# Name: url, Length: 387, dtype: object
