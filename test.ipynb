# %%
import pandas as pd

# %%
df_path = r"C:\Users\nurbe\OneDrive\Desktop\threads_parser\data\english\threads_suicide_en_1762836291.csv"
df = pd.read_csv(df_path)
df.head()
# Out:
#                                                 text  published_on  \
# 0  Cozy Crybaby Sweater | So Cute It Makes Me Sad...    1762275701
# 1                Free link will be posted here soon.    1762276220
# 2                                          xin với ạ    1762347823
# 3                                          Xin với ạ    1762439781
# 4                                                  🥰    1762479703
#
#                                 id         code        username  like_count  \
# 0  3758563458288309233_68233896006  DQpGY01CdPx  iphone_walls29         854
# 1  3758567814794403013_68233896006  DQpHYOJCVzF  iphone_walls29          39
# 2  3759168464520121790_68795852329  DQrP80yko2-        hn.mahn_           0
# 3  3759939858571790721_63444517918  DQt_WFfAQmB    forelsket_nh           0
# 4  3760274754545619637_64347645581  DQvLfdqj5K1       jemmilene           0
#
#    reply_count  image_count videos  \
# 0            0          NaN    NaN
# ...
